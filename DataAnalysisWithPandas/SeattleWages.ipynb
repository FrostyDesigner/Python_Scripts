# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Cards2.py',
#  'SeattleWages.ipynb',
#  'Seattle_Wages.csv',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testing.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
import pandas

# %%
df1=pandas.read_csv("Seattle_Wages.csv")
df1
# Out:
#                         Jobtitle  Female Avg Hrly Rate  No. Female Empl  \
# 0                     Accountant                 30.58             23.0
# 1                Accountant,Prin                 38.75             23.0
# 2                  Accountant,Sr                 34.48             23.0
# 3                       Act Exec                 43.10              4.0
# 4                    Actg Tech I                 22.56              1.0
# 5                 Actg Tech I-BU                 22.56             10.0
# 6                   Actg Tech II                 23.98              7.0
# 7                Actg Tech II-BU                 24.19             74.0
# 8                  Actg Tech III                 26.64              7.0
# 9               Actg Tech III-BU                 26.69             32.0
# 10               Actg Tech II-MC                 24.35              2.0
# 11             Actg Tech Supv-BU                 28.84              4.0
# ...

# %%
df1.iloc[5:500, 1:12]
# Out:
#      Female Avg Hrly Rate  No. Female Empl  \
# 5                   22.56             10.0
# 6                   23.98              7.0
# 7                   24.19             74.0
# 8                   26.64              7.0
# 9                   26.69             32.0
# 10                  24.35              2.0
# 11                  28.84              4.0
# 12                  22.35             15.0
# 13                  22.43             78.0
# 14                  24.32             28.0
# 15                  24.25            140.0
# 16                  26.10             12.0
# 17                  25.94             30.0
# 18                  26.26              1.0
# 19                  24.35             28.0
# 20                  22.56             16.0
# 21                  35.59             40.0
# 22                  30.86             54.0
# 23                  20.61              1.0
# 24                  20.30             10.0
# 25                    NaN              NaN
# ...
