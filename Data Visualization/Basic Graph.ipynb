# %%
# Making a basic Bokeh line graph

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some data
#lists must have the same length (count of objects)
x=[1,2,3,4,5]
y=[6,7,8,9,10]

#prepare the output file
output_file("Line.html")

#create a figure object
f = figure()

#create a line plot
f.line(x,y)

#write the plot in the figure object
show(f)

# %%
# Making a basic Bokeh line graph

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some data
#lists must have the same length (count of objects)
x=[3,7.5,10]
y=[3,6,9]

#prepare the output file
output_file("Line.html")

#create a figure object
f = figure()

#create a line plot
f.circle(x,y)

#write the plot in the figure object
show(f)

# %%
# Making a basic Bokeh line graph

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some data
#lists must have the same length (count of objects)
x=[3,7.5,10]
y=[3,6,9]

#prepare the output file
output_file("Line.html")

#create a figure object
f = figure()

#create a line plot
f.triangle(x,y)

#write the plot in the figure object
show(f)

# %%
# Making a basic Bokeh line graph

#importing Bokeh and pandas
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas

#prepare some data
#lists must have the same length (count of objects)
df=pandas.read_csv("data.csv")
x=df["x"]
y=df["y"]

#prepare the output file
output_file("Line_from_csv.html")

#create a figure object
f = figure()

#create a line plot
f.triangle(x,y)

#write the plot in the figure object
show(f)

# %%
df["x"]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: x, dtype: int64

# %%
#Bokeh Line Graph

#importing Bokeh and pandas
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas

#prepare some data
#lists must have the same length (count of objects)
df=pandas.read_csv("bachelors.csv")
x=df["Year"]
y=df["Engineering"]
z=df["Agriculture"]
#w=df["Art"]    #fail on purpose
w=df["Art and Performance"]
u=df["Communications and Journalism"]

#prepare the output file
output_file("Line_from_csv.html")

#create a figure object
f = figure()

#create a line plot with f
f.triangle(x,y)
f.circle(x+1,y+1)
f.line(x+2,y+2)
f.line(x,z)
f.line(x,w, legend="Art and Performance")
f.line(x,u, legend="Communications and Journalism")

#try for legend
f.legend.label_text_font = "times"
f.legend.location = "bottom_left"

#create a figure object and prepare the plot properties
#p=figure()
p=figure(plot_width=500,plot_height=400, tools='pan',logo=None)


p.title.text="Student Majors Through Time"
p.title.text_color="Gray"
p.title.text_font="times"
p.title.text_font_style="bold"
p.xaxis.minor_tick_line_color=None
p.yaxis.minor_tick_line_color=None
p.xaxis.axis_label="Date"
p.yaxis.axis_label="Number of Students"


#create a line plot with p
p.triangle(x,y, legend="Engineering")
p.circle(x+1,y+1)
p.line(x+2,y+2)
p.line(x,z, line_color="red", line_dash=[2, 4], line_width=4, legend="Agriculture")
p.line(x,w, line_color="green", legend="Art and Performance")
p.line(x,u, line_color="orange", line_dash=[4, 4], line_width=2, legend="Communications and Journalism")

#try for legend
p.legend.label_text_font = "arial"
p.legend.location = "bottom_left"

#write the plot in the figure object
show(f)
show(p)
