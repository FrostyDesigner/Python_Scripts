# %%
import requests
from bs4 import BeautifulSoup

#store requests in r variable
r=requests.get("http://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c=r.content
#print(c)

soup=BeautifulSoup(c,"html.parser")

#create list with all div elements that class of propoerty row
all=soup.find_all("div", {"class": "propertyRow"})
#type(all)
#len(all)
#print(all)

#you can use find_all to find all elements such as tags etc
#but you can also use it find the elements of a returned list
#all[0].find_all()
#all[0].find("h4",{"class":"propPrice"})
#all[0].find("h4",{"class":"propPrice"}).text
#type(all[0].find("h4",{"class":"propPrice"}).text)
#all[0].find("h4",{"class":"propPrice"}).text.replace("\n","")
#do a double replace
all[0].find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ", "")

#to merge cells select the first cell and go into command mode by pushing the escape key
#then hold shift + j to select the next cell until you have selected all cells you want to merge (or up with k)
#then press shift + m and all cells will merge
# Out:
# '$725,000'

# %%
#keep all as variable to ref entire object
#print(all)

# %%
for item in all:
    print(item.find("h4",{"class":"propPrice"}).text.replace("\n","").replace(" ", ""))
    #must use find_all because there are mulitiple items that match in the span tag (propAddressCollapse)
    #print(item.find_all("span", {"class": "propAddressCollapse"}))
    #apply a zero index to grab the first item in the list
    #print(item.find_all("span", {"class": "propAddressCollapse"})[0])
    #apply a one index to grab the second item in the list
    #print(item.find_all("span", {"class": "propAddressCollapse"})[1])
    #now parse for readability - apply text method
    print(item.find_all("span", {"class": "propAddressCollapse"})[0].text)
    print(item.find_all("span", {"class": "propAddressCollapse"})[1].text)
    #print(item.find("span",{"class":"infoBed"}))
    #if the text method is used on an object that has a None value, the program fails
    try:
        #returns all objects in the tag - need to filter the strings out
        #print(item.find("span",{"class":"infoBed"}).text)
        print(item.find("span",{"class":"infoBed"}).find("b").text)
    except:
        print(None)
    
    try:
        print(item.find("span",{"class":"infoSqFt"}).find("b").text)
    except:
        print(None)
    
    try:
        print(item.find("span",{"class":"infoValueFullBath"}).find("b").text)
    except:
        print(None)
    
    try:
        print(item.find("span",{"class":"infoValueHalfBath"}).find("b").text)
    except:
        print(None)
        
    #add blank line for readability
    print("")
# Out:
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
# None
# None
# None
# None
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
# 4
# None
# 4
# None
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
# 5
# 3,154
# 3
# None
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
# 4
# 3,076
# 3
# 1
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
# 3
# 1,172
# 3
# None
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
# 4
# 1,932
# 2
# None
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
# 4
# 1,676
# 3
# None
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
# 3
# 1,344
# 2
# None
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
# 3
# 1,920
# 2
# None
#
# $196,900
# 4 Minnies Lane
# Rock Springs, WY 82901
# 3
# 1,664
# 2
# None
